# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Cellphone.csv')

# %%
df=data.copy()

# %%
df
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# ...

# %%
df.head(5)
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.tail(5)
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem  ram  RearCam  Front_Cam  battery  thickness
# 156         128.0  6.0     12.0       16.0     4080        8.4
# 157         128.0  6.0     20.0        8.0     3400        7.9
# 158          64.0  4.0     20.0       20.0     3000        6.8
# 159         128.0  6.0     20.0        8.0     3400        7.9
# 160          16.0  3.0     21.5       16.0     2700        8.4

# %%
df.shape
# Out:
# (161, 14)

# %%
df.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %% [markdown]
# # Avarge of sales

# %%
df['Sale'].mean()
# Out:
# 621.4658385093168

# %% [markdown]
# # Avarge of price

# %%
df['Price'].mean()
# Out:
# 2215.5962732919256

# %% [markdown]
# # The highest price

# %%
df['Price'].max()
# Out:
# 4361

# %% [markdown]
# # Top 5 prices

# %%
df['Price'].nlargest(5)
# Out:
# 152    4361
# 153    4361
# 83     3837
# 87     3837
# 53     3658
# Name: Price, dtype: int64

# %% [markdown]
# # Lowest 5 prices

# %%
df['Price'].nsmallest(5)
# Out:
# 149    614
# 150    614
# 140    628
# 141    628
# 125    705
# Name: Price, dtype: int64

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
# ...

# %%
df.groupby('Price').mean()['Sale']
# Out:
# Price
# 614     2165.0
# 628     1249.0
# 705      425.0
# 754      303.5
# 791      110.0
#          ...
# 3316      33.5
# 3551    4523.0
# 3658      48.5
# 3837     115.0
# 4361    3269.5
# Name: Sale, Length: 81, dtype: float64

# %%
df.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
sns.scatterplot('Sale', 'Price',data=df)
# Out:
# <AxesSubplot:xlabel='Sale', ylabel='Price'>

# %%
df.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
sns.scatterplot('resoloution','RearCam', data=df, hue='Front_Cam')
# Out:
# <AxesSubplot:xlabel='resoloution', ylabel='RearCam'>

# %%
sns.scatterplot('weight','thickness', data=df, hue='Price')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='thickness'>

# %%
sns.kdeplot('Sale',data=df)
# Out:
# <AxesSubplot:xlabel='Sale', ylabel='Density'>

# %%
sns.displot(x='Sale',data=df ,col='Price',kde=True)
